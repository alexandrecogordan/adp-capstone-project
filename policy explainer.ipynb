# %%
POLICIES = {
"retirement": """Every eligible employee can contribute between 1% and 100% of their salary to the 401(k) plan,
up to the annual IRS limits, which are $23,000 for 2024 or $30,500 if you’re 50 or older and
eligible for catch-up contribuons. You can adjust your contribuon percentage at any me
through our online portal, and changes typically take effect with the next payroll processing.
TechLance’s matching formula is designed to reward your rerement savings commitment with a
generous company contribuon. We provide a dollar-for-dollar match on your first 4% of salary
contribuons, plus an addional 50% match on your next 2% of contribuons. This means that if
you contribute 6% of your salary, TechLance will contribute 5%, creang total annual rerement
savings of 11% of your salary.
For example, if you earn $60,000 annually and contribute 6% ($3,600), TechLance will contribute
$3,000 (4% at 100% match plus 1% at 50% match), bringing your total annual rerement savings
to $6,600. This represents free money that significantly accelerates your rerement savings,
making it essenal to contribute at least enough to receive the full company match.
Our matching contribuons are subject to a vesng schedule that encourages long-term
employment while protecng the company’s investment in your rerement. You’re always 100%
vested in your own contribuons, but company matching vests gradually over five years: 20%
aer one year, 40% aer two years, 60% aer three years, 80% aer four years, and 100% aer
five years of service.

TechLance automacally enrolls all eligible employees (age 21 and older, working at least 1,000
hours annually) on the first day of the month following 90 days of employment. Automac
enrollment starts you at 4% of your salary, which is enough to receive significant company
matching and establishes good savings habits from the beginning.
If you prefer not to parcipate in the 401(k) plan, you can opt out during your first 90 days and
receive a refund of any contribuons made. However, we strongly encourage parcipaon since
the combinaon of tax benefits and company matching makes the 401(k) plan one of the most
valuable benefits we offer.
The plan also includes automac escalaon, which increases your contribuon rate by 1% each
year on your hire date anniversary, up to 10% of your salary. This feature helps you gradually
increase your rerement savings as your income grows and you become more comfortable with
the contribuon amounts. You can opt out of automac escalaon or adjust the increases at any
me.
These automac features are designed to help you build substanal rerement savings without
requiring constant aenon or difficult decisions. Research shows that employees who
parcipate in automac enrollment and escalaon typically accumulate significantly more
rerement wealth than those who don’t, even when controlling for income and other factors.

Our 401(k) plan offers a carefully selected menu of investment opons designed to meet diverse
needs and risk tolerances while keeping costs low. The cornerstone of our investment lineup is a
series of target-date funds that provide professional porolio management and automac
adjustment of your investment mix as you approach rerement.
Target-date funds are named for approximate rerement years (2030, 2040, 2050, 2060) and
automacally become more conservave as you get older. These funds start with higher
allocaons to stocks when you’re young and gradually shi toward bonds and more stable
investments as you approach rerement. Target-date funds are excellent default opons for
employees who want professional management without the complexity of building their own
porolios.
For employees who prefer to construct their own porolios, we offer core investment opons
including large-cap growth and value funds, mid-cap and small-cap funds, internaonal developed
and emerging market funds, bond funds, and stable value opons. All of our core funds are lowcost index funds with expense raos ranging from 0.05% to 0.25%, ensuring that high fees don’t
erode your long-term returns.
We also offer a self-directed brokerage opon for experienced investors who want access to a
broader universe of investments including individual stocks, ETFs, and addional mutual funds.
This opon carries a $25 quarterly maintenance fee and $4.95 per trade, but it provides
maximum flexibility for employees who want to implement specific investment strategies.
Investment performance and expense raos are monitored regularly, and we replace funds that
specialized programming, higher-end amenies, and addional services such as personal training,
spa services, or specialized group fitness classes.
Tier 3 partners offer 25% discounts and encompass bouque studios specializing in specific
acvies such as yoga, Pilates, maral arts, rock climbing, CrossFit boxes, and sports-specific
facilies like tennis or racquetball clubs. While the discount is smaller, these partnerships provide
access to specialized instrucon and communies focused on parcular fitness interests.
The specific facilies available and discount levels may vary by geographic locaon, and we
regularly evaluate and add new partners based on employee feedback and requests. Employees
can browse all available partners through our benefits portal, which includes detailed informaon
about each facility’s amenies, class schedules, and member reviews.

Our fitness benefits extend to employees’ family members, making it easier for households to
maintain healthy lifestyles together. Spouses and domesc partners receive the same discount
rates as employees when they enroll in partner facilies. Dependent children under 18 receive an
addional 10% discount on youth programs and classes, while adult children between 18 and 26
who are covered under the employee’s health insurance are eligible for the same rates as
employees.
Family members must be added to fitness memberships during the employee’s inial enrollment
period or during qualifying life events such as marriage, birth, or adopon. Each family member
must complete their own enrollment documentaon and meet any age or health requirements
established by the specific fitness facility.
In addion to tradional gym memberships, all TechLance employees and their families have
complimentary access to our curated online fitness plaorm, which includes workout videos,
wellness content, and live virtual classes. We also provide premium subscripons to popular
fitness apps such as Peloton Digital, Nike Training Club, and Headspace for meditaon and
mindfulness training.

Geng started with our fitness benefits is straighorward, though it requires some planning and
documentaon. All acve full-me and part-me employees working at least 20 hours per week
are eligible for fitness benefits immediately upon hire, with no waing period or probaonary
requirements.
To enroll, employees first browse available fitness partners through our benefits portal,
comparing locaons, amenies, class schedules, and member rangs. Once you’ve selected a
preferred facility, you’ll need to complete the enrollment process through our portal, uploading
employment verificaon documents such as a recent pay stub or HR verificaon leer, along with
photo idenficaon and emergency contact informaon.
Most fitness centers also require compleon of a basic health quesonnaire and liability waiver
before beginning membership. Some facilies may have addional requirements or capacity
limitaons that could affect immediate availability.
TechLance offers two payment opons for fitness memberships. Payroll deducon is the most
popular choice, allowing automac monthly deducon from your paycheck using pre-tax dollars
through our Flexible Spending Account program. This opon provides immediate tax savings and
ensures that your membership payments are consistent even if membership fees increase.
Alternavely, you can choose to pay the fitness center directly, which offers more flexibility for
pausing or modifying memberships but doesn’t provide the same tax advantages.

Once enrolled, you’ll receive a TechLance corporate membership card that idenfies you as a
corporate member and ensures you receive the negoated discount rates. You’ll also need to
present photo idenficaon during inial setup and periodic verificaon visits. Some locaons
may also require your TechLance employee badge for verificaon.
Most partner locaons provide guest privileges as part of corporate memberships, typically
allowing two guest passes per month at standard partner facilies. Addional guest visits are
available at reduced day rates, and all guests must be at least 18 years old and sign liability
waivers. Premium locaons such as Equinox may limit guest privileges to one pass per month,
and some bouque studios may not offer guest access at all.
Class booking and cancellaon policies vary by facility, but most allow you to reserve popular
classes up to seven days in advance through their mobile apps or websites. To avoid fees, you
should cancel class reservaons at least two hours before the scheduled start me. Excessive noshows may result in booking restricons, so it’s important to be realisc about your schedule
when making reservaons.
General fitness center equee applies to all TechLance members, including me limits on cardio
equipment during peak hours, wiping down equipment aer use, allowing others to work in
during rest periods, and following all posted safety guidelines. Appropriate athlec are and
closed-toe shoes are required at all facilies, and members should respect locker room privacy
and cleanliness standards.
""",

    "healthcare": """Our PPO plan offers the greatest flexibility in choosing healthcare providers and doesn’t require
referrals to see specialists. This plan works well for employees who want the freedom to visit any
doctor or specialist without coordinang through a primary care physician, though you’ll pay less
when you use providers within our extensive naonwide network. The PPO includes a moderate
deducble and copays for most services, making it predictable for budgeng healthcare costs.
The HMO plan provides comprehensive coverage through a more structured approach that
emphasizes coordinated care and prevenve services. With this plan, you’ll choose a primary care
physician who will coordinate your healthcare and provide referrals when specialist care is
needed. The HMO typically offers the lowest out-of-pocket costs for employees, with minimal
deducbles and low copays for covered services. However, except for emergency care, services
are only covered when you use providers within the HMO network.
Our High Deducble Health Plan (HDHP) is designed for employees who want to take a more
acve role in managing their healthcare costs while building tax-advantaged savings for future
medical expenses. This plan has a higher deducble than our other opons, but it’s paired with a
Health Savings Account that allows you to set aside pre-tax dollars for healthcare expenses. The
HDHP uses the same provider network as our PPO plan, giving you flexibility in choosing
providers once you meet the deducble.

Employee-only coverage costs range from $32 per month for the HDHP to $89 per month for the
PPO plan, with the HMO falling in between at $45 monthly. Family coverage varies significantly
depending on the plan you choose and whether you’re covering a spouse, children, or a full
family. The PPO family coverage costs $245 monthly, while HMO family coverage is $189, and
HDHP family coverage is just $134 per month.
These employee contribuons represent only a poron of the actual premium costs, with
TechLance subsidizing the majority of your health insurance expenses. We review our
contribuon levels annually to ensure they remain compeve and sustainable while providing
maximum value to our employees.
All plans include comprehensive prevenve care at no cost to you when you use in-network
providers. This includes annual physical exams, roune immunizaons, cancer screenings like
mammograms and colonoscopies, women’s health exams, well-child visits, and annual vision and
hearing tests. Prevenve care coverage helps you stay healthy and catch potenal health issues
early when they’re most treatable.
The prescripon drug coverage varies by plan but generally includes four ers of medicaons
with different cost-sharing levels. Generic medicaons (Tier 1) have the lowest copays, typically
around $10 for a 30-day supply, while brand-name and specialty medicaons have higher copays
or coinsurance requirements. You can save money by using mail-order pharmacy services for 90-
day supplies of maintenance medicaons.

Each plan has different cost-sharing structures that determine how much you’ll pay for various
services. Copays are fixed amounts you pay for specific services, like $25 for a primary care visit,
while coinsurance means you pay a percentage of the total cost aer meeng your deducble.
For example, if your plan has 20% coinsurance for hospital stays, you would pay 20% of the
hospital bill aer your deducble is met, up to your annual out-of-pocket maximum.
The annual deducble is the amount you must pay out-of-pocket before your insurance begins
paying for most services. However, prevenve care and some other services are covered even
before you meet your deducble. Once you reach your annual out-of-pocket maximum, your
insurance covers 100% of covered services for the rest of the year.
In-network providers have contracts with our insurance company that result in lower costs for
both you and the insurance plan. Out-of-network providers don’t have these contracts, which
typically means higher costs and more paperwork for you. While our PPO and HDHP plans
provide some coverage for out-of-network care, the HMO plan only covers out-of-network care
in emergency situaons.

To find in-network providers, you can use the insurance company’s online directory, download
their mobile app, or call the customer service number on your insurance card. It’s important to
verify that providers are sll in-network before scheduling appointments, as networks can change
periodically.
Some services require prior authorizaon from the insurance company before they’ll be covered.
This typically includes expensive procedures like MRIs and CT scans, specialist surgeries, durable
medical equipment over $500, and extended physical therapy. Your doctor’s office usually
handles prior authorizaon requests, but it’s important to verify coverage before receiving these
services to avoid unexpected costs.
For most services with in-network providers, you’ll simply pay your copay or coinsurance at the
me of service, and the provider will handle billing the insurance company directly. If you use outof-network providers, you may need to pay the full amount upfront and then submit claims to the
insurance company for reimbursement.

TechLance employees enrolled in the HDHP are eligible to contribute to a Health Savings
Account, which offers significant tax advantages. You can contribute up to $4,150 annually for
individual coverage or $8,300 for family coverage in 2024, with an addional $1,000 catch-up
contribuon allowed if you’re 55 or older. TechLance contributes $750 annually for individual
HDHP coverage and $1,500 for family coverage, deposited quarterly into your HSA.
HSA funds can be used to pay for qualified medical expenses tax-free, and any unused money
rolls over from year to year. Aer age 65, you can withdraw HSA funds for any purpose without
penalty, though non-medical withdrawals will be subject to income tax. This makes the HSA not
just a healthcare benefit but also a valuable rerement savings tool.
Our wellness program offers opportunies to earn up to $300 annually in HSA contribuons or
health insurance premium credits. You can earn $100 for compleng an annual biometric
screening, $50 for finishing a health assessment, and up to $150 for parcipang in various
wellness challenges throughout the year. These programs are designed to help you stay healthy
while reducing your healthcare costs.
All employees have access to telemedicine services at no cost, regardless of which health plan
they choose. These virtual consultaons are available 24/7 for non-emergency medical issues and
can oen provide convenient care without the need to visit a doctor’s office. The telemedicine
plaorm can also prescribe medicaons when appropriate and is parcularly useful for minor
illnesses, follow-up care, and urgent medical quesons.
""",

    "life insurance" : """Every eligible TechLance employee automacally receives basic life insurance coverage equal to
one mes their annual base salary, with a maximum benefit of $100,000. This coverage is
provided at no cost to you and begins on your first day of employment with no waing period or
medical requirements. The coverage amount adjusts annually based on your current salary, so if
you receive raises or promoons, your basic life insurance coverage increases accordingly.
For example, if your annual salary is $45,000, your basic life insurance coverage would be
$45,000. If you earn $75,000 annually, your coverage would be $75,000. However, if your salary
exceeds $100,000, your basic coverage would be capped at the $100,000 maximum. This
automac coverage ensures that every employee has some level of protecon for their family
without any acon required on their part.
The basic life insurance coverage also includes an equal amount of accidental death and
dismemberment (AD&D) coverage at no addional cost. AD&D coverage provides the full benefit
amount in case of accidental death and paral benefits for specific injuries such as loss of limbs or
sight. This coverage is effecve 24 hours a day, seven days a week, anywhere in the world.
While the basic coverage provides a foundaon of protecon, it may not be sufficient for
employees with significant financial obligaons or dependents. We encourage all employees to
evaluate their total insurance needs and consider whether supplemental coverage would be
appropriate for their situaon.

TechLance offers voluntary supplemental life insurance that allows you to purchase addional
coverage beyond the basic amount provided by the company. Supplemental coverage is available
in increments of $10,000, ranging from $50,000 to $500,000, with a maximum total coverage
(including basic) of five mes your annual salary or $1,000,000, whichever is less.
The cost of supplemental life insurance is based on your age and whether you use tobacco
products, with rates calculated per $1,000 of coverage per month. For example, a 35-year-old
non-smoker would pay approximately $0.12 per month for each $1,000 of coverage, which
means $100,000 of supplemental coverage would cost about $12 per month. Rates increase with
age, so a 45-year-old non-smoker would pay approximately $0.28 per month per $1,000 of
coverage.
Tobacco users pay significantly higher rates due to increased health risks, with rates typically
double or more compared to non-tobacco users. The insurance company defines tobacco use as
any use of cigarees, cigars, pipes, or smokeless tobacco products within the past 12 months.
For coverage amounts up to $150,000, no medical exam or health quesons are required if you
enroll within 30 days of becoming eligible or during annual open enrollment. However, if you
want coverage exceeding $150,000, or if you’re enrolling outside of the inial eligibility period,
you’ll need to complete evidence of insurability forms and possibly undergo a medical exam at no
cost to you.

TechLance also offers life insurance coverage for your spouse or domesc partner and dependent
children, providing addional financial protecon for your family. Spouse coverage is available in
amounts of $10,000, $25,000, $50,000, or $75,000, though the total amount cannot exceed 50%
of your own life insurance coverage (basic plus supplemental combined).
The cost of spouse coverage is based on their age and follows a similar rate structure to
employee supplemental coverage. For coverage amounts over $50,000, your spouse may need to
complete health quesonnaires or undergo medical underwring, depending on their age and
health status.
Dependent child coverage is available for children from 14 days old through age 26 if they qualify
as dependents under your health insurance. Coverage amounts are $5,000 or $10,000 per child,
and one premium covers all eligible children in your family. Child life insurance costs only $2-4
per month regardless of how many children you have, and no medical exams are required.
While child life insurance provides relavely small death benefits, it can help cover final expenses
and provides the valuable benefit of guaranteed future insurability. Children covered under the
company plan can typically convert to individual coverage when they’re no longer eligible as
dependents, regardless of their health status at that me.

One of the most important aspects of life insurance is ensuring that you have current,
appropriate beneficiary designaons. You must designate at least one primary beneficiary within
30 days of your coverage becoming effecve. Beneficiaries can be individuals, organizaons such
as charies, or legal enes such as trusts.
You can name mulple primary beneficiaries and specify the percentage each should receive, and
these percentages must total 100%. It’s also wise to name conngent beneficiaries who would
receive the proceeds if your primary beneficiaries predecease you. Without conngent
beneficiaries, the insurance proceeds could end up being paid to your estate, which might create
tax complicaons and delays for your family.
Updang your beneficiaries is simple and can be done at any me through our online benefits
portal. We strongly recommend reviewing your beneficiaries annually and always aer major life
events such as marriage, divorce, birth or adopon of children, or death of a previously named
beneficiary. Changes become effecve immediately upon submission through the portal.
When a claim needs to be filed, beneficiaries should contact the insurance company or TechLance
HR as soon as possible. The claims process typically requires a cerfied death cerficate,
completed claim forms, and idenficaon from the beneficiary. Most claims are processed within
30 days once all required documentaon is received.
"""
    
}

# %%
# !pip install -qU openai==1.60.2
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# litellm 1.65.8 requires openai>=1.68.2, but you have openai 1.60.2 which is incompatible.

# %%
import os
import getpass
from openai import OpenAI

if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")

client = OpenAI()
# Out:
# Enter your OpenAI API key:  ········

# %%
import pandas as pd

def get_response(messages, model = "gpt-4o", max_length=300):
    """
    Generate a response using the chat completions API
    """
    try:
        response = client.chat.completions.create(
            model=model,
            messages=messages,
            max_tokens=max_length
        )
        return response.choices[0].message.content
    except Exception as e:
        print(f"Error generating response: {e}")
        return None

def get_employee_context(employee_id):
    df = pd.read_csv('assets/data/employee_data.csv')
    employee = df[df['EmployeeID'] == employee_id].iloc[0]
    print(employee)
    print(f"Employee: {employee['Age']} years old, {employee['Tenure']} years tenure, {employee['Department']} department, {employee['Gender']}")
    return f"Employee: {employee['Age']} years old, {employee['Tenure']} years tenure, {employee['Department']} department, {employee['Gender']}"

employee_id_str = input("What is your employee ID?")
employee_id=int(employee_id_str)
#employee_id=15
employee_context=get_employee_context(employee_id)

messages = [{"role": "system", "content": ""}]

user_input = input("What policy can I help you with today? To finish this conversation please write 'quit'.")
while user_input != "quit":

    #rag_content = rag_function(user_input) #ne retourne rien si il n'y a pas de questions sur les policies

    #if rag_content:
    #    policy_context = f"Use this policy info: {rag_content}"
    #else:
    #    policy_context = "Use conversation history to provide helpful guidance."
        
    messages[0]["content"] = f"""You are TechLance's AI assistant specializing in employee policies.

         ROLE: Translate complex policies into clear, actionable advice
         STYLE: Professional yet conversational, concise but complete and helpful tone
         PERSONALIZATION: Tailor all responses to this employee profile: {employee_context}

         GUIDELINES:
         - Use simple language, avoid jargon
         - Give specific numbers, dates, and examples
         - Focus on what matters most to THIS employee
         - Keep responses under 150 words unless complex calculations needed
         - Always explain "why this matters to you"
         - If policy doesn't apply to this employee, explain why
         
         Use this policy info: {POLICIES}""" # use rag_content instead of POLICIES
    
    messages.append({"role": "user", "content": user_input})
    
    assistant_response = get_response(messages)
    print(f"Assistant: {assistant_response}")
    messages.append({"role": "assistant", "content": assistant_response})
    user_input = input("")
# Out:
# What is your employee ID? 1
# EmployeeID       1
# Age             62
# Gender        Male
# Department      IT
# Tenure           8
# Name: 0, dtype: object
# Employee: 62 years old, 8 years tenure, IT department, Male
# What policy can I help you with today? To finish this conversation please write 'quit'. quit

# %%
### Testing
import os
import getpass
import pandas as pd
import giskard
from giskard import Model, Dataset, scan

current_model="gpt-4o-mini"
giskard.llm.set_llm_model(current_model)
print("✅ Environment setup complete!")
# Out:
# ✅ Environment setup complete!

# %%
def policy_assistant(df):
    responses = []
    
    for query in df['customer_query']:
        # Include the actual query in the messages
        messages = [
            {
                "role": "system", 
                "content": f"""You are TechLance's AI assistant specializing in employee policies.

ROLE: Translate complex policies into clear, actionable advice
STYLE: Professional yet conversational, concise but complete and helpful tone
PERSONALIZATION: Tailor all responses to this employee profile: {employee_context}

GUIDELINES:
- Use simple language, avoid jargon
- Give specific numbers, dates, and examples
- Focus on what matters most to THIS employee
- Keep responses under 150 words unless complex calculations needed
- Always explain "why this matters to you"
- If policy doesn't apply to this employee, explain why

CONSISTENCY RULES:
- Use the same format and key details for similar policy questions
- Treat synonyms the same way (401k = 401(k) = retirement plan = retirement savings)
- Always include the most important facts first
- Use consistent terminology throughout

Use this policy info: {POLICIES}"""
            },
            {
                "role": "user", 
                "content": query  
            }
        ]
        
        response = client.chat.completions.create(
            model=current_model,
            messages=messages,
            max_tokens=300,
            temperature=0.8,
        )
        
        responses.append(response.choices[0].message.content)
    
    return responses

# %% [markdown]
# ## Robustness test

# %%
import giskard as gsk
import pandas as pd

employee_id = 15  # Fixed for testing
employee_context = get_employee_context(employee_id)

# Create Giskard model and dataset
giskard_model_basic = gsk.Model(
    model=policy_assistant,  # Use your function name
    model_type="text_generation",
    name="Policy Assistant Robustness Test",
    description="Employee policy assistant that must provide consistent answers",
    feature_names=["customer_query"]
)

dataset = gsk.Dataset(pd.DataFrame({
    'customer_query': [  
        #"What is the 401k policy?",
        #"What is the 401(k) policy?", 
        #"Tell me about the retirement plan",
        #"What's our retirement savings plan?",

        "How much does the company match?",
        "What's the employer match?",
        "How much matching do we get?",
        "What's the company contribution?",

        #"How much can I contribute?",
        #"What's the maximum contribution?",
        #"What are the contribution limits?",
        #"How much should I put in?",
    ]
}))

# Test robustness
test_result = giskard.testing.tests.llm.test_llm_output_against_requirement(
    model=giskard_model_basic,
    dataset=dataset, 
    requirement="Different ways of asking about the same policy should provide substantially similar information and cover the same main policy points, even if the wording or examples vary slightly.",
)
# Out:
# EmployeeID       15
# Age              36
# Gender         Male
# Department    Sales
# Tenure            4
# Name: 14, dtype: object
# Employee: 36 years old, 4 years tenure, Sales department, Male
# 2025-08-25 17:06:10,469 pid:30745 MainThread giskard.models.automodel INFO     Your 'prediction_function' is successfully wrapped by Giskard's 'PredictionFunctionModel' wrapper class.
# 2025-08-25 17:06:10,473 pid:30745 MainThread giskard.datasets.base INFO     Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/giskard/core/dataset_validation.py:19: UserWarning: You did not provide the optional argument 'target'. 'target' is the column name in df corresponding to the actual target variable (ground truth).
#   warning(

# %%
result = test_result.execute()

print("=== TEST SUMMARY ===")
print(f"Passed: {result.passed}")
print(f"Failed Tests: {result.metric}")
print()

print("=== INDIVIDUAL RESULTS ===")
questions = result.details.inputs['customer_query']
responses = result.details.outputs
test_results = result.details.results

for i, (question, response, status) in enumerate(zip(questions, responses, test_results)):
    print(f"\n--- Question {i+1}: {status} ---")
    print(f"Q: {question}")
    print(f"A: {response}...") 
    print()
# Out:
# 2025-08-25 17:06:12,153 pid:30745 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'customer_query': 'object'} to {'customer_query': 'object'}
# 2025-08-25 17:06:32,512 pid:30745 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (4, 1) executed in 0:00:20.365664
# === TEST SUMMARY ===
# Passed: True
# Failed Tests: 0
#
# === INDIVIDUAL RESULTS ===
#
# --- Question 1: PASSED ---
# Q: How much does the company match?
# ...
